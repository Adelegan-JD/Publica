# %% [markdown]
# # **Ingesting Datasets From Different Sources**

# %% [markdown]
# #### **From Github**

# %%
import pandas as pd
import numpy as np

# %%
# For data separated by commas

url = 'https://raw.githubusercontent.com/Adelegan-JD/Datasets/refs/heads/master/Practice_datasets-main/estonia-passenger-list.csv'

pd.read_csv(url)
# Out:
#      PassengerId  Country             Firstname  Lastname Sex  Age Category  \
# 0              1   Sweden           ARVID KALLE     AADLI   M   62        P
# 1              2  Estonia                   LEA   AALISTE   F   22        C
# 2              3  Estonia                  AIRI   AAVASTE   F   21        C
# 3              4   Sweden                  JURI     AAVIK   M   53        C
# 4              5   Sweden       BRITTA ELISABET  AHLSTROM   F   55        P
# ..           ...      ...                   ...       ...  ..  ...      ...
# 984          985   Sweden  ANNA INGRID BIRGITTA    OSTROM   F   60        P
# 985          986   Sweden          ELMAR MIKAEL       OUN   M   34        P
# 986          987   Sweden                   ENN   QUNAPUU   M   77        P
# 987          988   Sweden                    LY   GUNAPUU   F   87        P
# 988          989   Sweden                  CARL    OVBERG   M   42        P
#
#      Survived
# 0           0
# 1           0
# ...

# %%
# For data separated by semicolons

link = 'https://raw.githubusercontent.com/Adelegan-JD/Datasets/refs/heads/master/Practice_datasets-main/bank-full.csv'

pd.read_csv(link, sep=';', header = 0)
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %% [markdown]
# #### **From Google Drive**

# %%
# install gdown to access Google Drive

# %pip install gdown
# Out:
# ...
#
#    ----------------------------------------  0/12 [urllib3]
#    ----------------------------------------  0/12 [urllib3]
#    ----------------------------------------  0/12 [urllib3]
#    ----------------------------------------  0/12 [urllib3]
#    ----------------------------------------  0/12 [urllib3]
#    ----------------------------------------  0/12 [urllib3]
#    ----------------------------------------  0/12 [urllib3]
#    ----------------------------------------  0/12 [urllib3]
#    ----------------------------------------  0/12 [urllib3]
#    ----------------------------------------  0/12 [urllib3]
#    ----------------------------------------  0/12 [urllib3]
#    ----------------------------------------  0/12 [urllib3]
#    ----------------------------------------  0/12 [urllib3]
#    ----------------------------------------  0/12 [urllib3]
#    ----------------------------------------  0/12 [urllib3]
#    ----------------------------------------  0/12 [urllib3]
# ...

# %%
# Get the raw link or url from  Google Drive and copy it here
# import gdown

import gdown as gd

rawlink = 'https://drive.google.com/file/d/13ejsAq76ZQfyAHPs4uCMn2jaiB6lfuDb/view?usp=sharing'
id = '13ejsAq76ZQfyAHPs4uCMn2jaiB6lfuDb'

# %%
gd.download(f'https://drive.google.com/uc?id={id}', quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=13ejsAq76ZQfyAHPs4uCMn2jaiB6lfuDb
# To: c:\Users\ncc\Desktop\AI_Engineering\Publica\Week_8\Accidents.csv
# 100%|██████████| 72.3M/72.3M [00:23<00:00, 3.04MB/s]
# 'Accidents.csv'

# %%
# load the datset
df= pd.read_csv('Accidents.csv')

# %%
# create a copy of the dataset so you don't alter the original data
df2 = df.copy()

# %%
# you can save the data on your system
df2_to_csv('Accidents2.csv', index=False)

# %% [markdown]
# #### **From Wikipedia**

# %%
import pandas as pd
import requests
import

# %%
# %pip install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/4.0 MB 1.3 MB/s eta 0:00:03
#    ------- -------------------------------- 0.8/4.0 MB 1.2 MB/s eta 0:00:03
#    ---------- ----------------------------- 1.0/4.0 MB 988.8 kB/s eta 0:00:03
#    ---------- ----------------------------- 1.0/4.0 MB 988.8 kB/s eta 0:00:03
#    ---------- ----------------------------- 1.0/4.0 MB 988.8 kB/s eta 0:00:03
#    ------------- -------------------------- 1.3/4.0 MB 767.2 kB/s eta 0:00:04
#    ------------- -------------------------- 1.3/4.0 MB 767.2 kB/s eta 0:00:04
#    ------------- -------------------------- 1.3/4.0 MB 767.2 kB/s eta 0:00:04
#    --------------- ------------------------ 1.6/4.0 MB 641.6 kB/s eta 0:00:04
# ...
